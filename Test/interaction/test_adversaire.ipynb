# %% [markdown]
# ## Test Adversaire

# %%
import sys
sys.path.insert(0, 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank')

# %%
from bandits_to_rank.bandits import *
from bandits_to_rank.environment import *
from bandits_to_rank.referee import *
from bandits_to_rank.opponents import oracle,random_player,greedy,bc_mpts

import time
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import floor, log
from random import shuffle
from copy import deepcopy


# %reload_ext autoreload
# %autoreload 2

# %%
def time_sec_to_HMS(sec):
    heure=sec//3600
    rest_h=sec%3600
    minute=rest_h//60
    rest_m=rest_h%60

    return(str(int(heure))+'H '+str(int(minute))+'min '+str(int(rest_m))+'sec')

# %% [markdown]
# ## Tests Egreedy

# %%
kappas_desord = [1,0.7,0.3,0.75,0.1]
thetas = [0.9,0.3,0.5,0.4,0.1,0.2,0.5,0.1,0.8,0.4]
nb_prop = len(thetas)  
nb_place = len(kappas_desord)

# %%
pas = 10
c = [10, 100, 1000,10000]
env = Environment_PBM(thetas,kappas_desord)

 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)


n_MAJ = 1
player_d_greedy_EGreedy_5 =  greedy.greedy_EGreedy(5,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_10 =  greedy.greedy_EGreedy(10,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_15 =  greedy.greedy_EGreedy(15,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_20 =  greedy.greedy_EGreedy(20,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_50 =  greedy.greedy_EGreedy(50,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_70 =  greedy.greedy_EGreedy(70,nb_prop,nb_place,n_MAJ)

# %% [markdown]
# ### Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_desord = Referee(env,nb_trial)
referee_Random_5000trials_20games_desord = Referee(env,nb_trial)


referee_greedy_EGreedy_5_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_15_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_20_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_50_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_70_5000trials_20games_desord = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_Oracle_5000trials_20games_desord.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_desord.play_game(player_d_Random)
    
    referee_greedy_EGreedy_5_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_5)
    referee_greedy_EGreedy_10_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_10)    
    referee_greedy_EGreedy_15_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_15)
    referee_greedy_EGreedy_20_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_20)
    referee_greedy_EGreedy_50_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_50)
    referee_greedy_EGreedy_70_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_70)


end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 20min 25sec

# %%
player_d_greedy_EGreedy_100 =  greedy.greedy_EGreedy(100,nb_prop,nb_place,n_MAJ)
referee_greedy_EGreedy_100_5000trials_20games_desord = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_greedy_EGreedy_100_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_100)

end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 0min 28sec

# %%
player_d_greedy_EGreedy_1000 =  greedy.greedy_EGreedy(1000,nb_prop,nb_place,n_MAJ)
referee_greedy_EGreedy_1000_5000trials_20games_desord = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_greedy_EGreedy_1000_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_1000)

end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 0min 24sec

# %%
player_d_greedy_EGreedy_500 =  greedy.greedy_EGreedy(500,nb_prop,nb_place,n_MAJ)
referee_greedy_EGreedy_500_5000trials_20games_desord = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_greedy_EGreedy_500_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_500)

end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 0min 23sec

# %%
player_d_greedy_EGreedy_150 =  greedy.greedy_EGreedy(150,nb_prop,nb_place,n_MAJ)
referee_greedy_EGreedy_150_5000trials_20games_desord = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_greedy_EGreedy_150_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_150)

end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 0min 23sec

# %%
player_d_greedy_EGreedy_90 =  greedy.greedy_EGreedy(90,nb_prop,nb_place,n_MAJ)
referee_greedy_EGreedy_90_5000trials_20games_desord = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_greedy_EGreedy_90_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_90)

end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 0min 26sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_greedy_EGreedy_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'b', label='greedy Egreedy,, c = 10')
#plt.plot(trials, np.cumsum(referee_greedy_EGreedy_15_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'black', label='greedy Egreedy,, c = 15')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_20_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'indigo',linestyle='--', label='greedy Egreedy,, c = 20')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_50_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'g', label='greedy Egreedy,, c = 50')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_70_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange', label='greedy Egreedy,, c = 70')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_75_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange',linestyle ='--', label='greedy Egreedy,, c = 75')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_90_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'plum', label='greedy Egreedy,, c = 90')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_100_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'cyan', label='greedy Egreedy,, c = 100')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_150_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', label='greedy Egreedy,, c = 150')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_1000_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'gray', label='greedy Egreedy,, c = 1000')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %%
##### first try 
trials = [i for i in range(referee_Oracle_5000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_greedy_EGreedy_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'b', label='greedy Egreedy,, c = 10')
#plt.plot(trials, np.cumsum(referee_greedy_EGreedy_15_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'black', label='greedy Egreedy,, c = 15')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_20_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'indigo',linestyle='--', label='greedy Egreedy,, c = 20')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_50_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'g', label='greedy Egreedy,, c = 50')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_70_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange', label='greedy Egreedy,, c = 70')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_75_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange',linestyle ='--', label='greedy Egreedy,, c = 75')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_90_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'plum', label='greedy Egreedy,, c = 90')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_100_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'cyan', label='greedy Egreedy,, c = 100')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_150_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', label='greedy Egreedy,, c = 150')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_1000_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'gray', label='greedy Egreedy,, c = 1000')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ### nb_MAJ=5

# %%
kappas_desord = [1,0.7,0.3,0.75,0.1]
thetas = [0.9,0.3,0.5,0.4,0.1,0.2,0.5,0.1,0.8,0.4]
nb_prop = len(thetas)  
nb_place = len(kappas_desord)

# %%
pas = 10
c = [10, 100, 1000,10000]
env = Environment_PBM(thetas,kappas_desord)

 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)


n_MAJ = 5
player_d_greedy_EGreedy_10 =  greedy.greedy_EGreedy(10,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_50 =  greedy.greedy_EGreedy(50,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_70 =  greedy.greedy_EGreedy(70,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_100 =  greedy.greedy_EGreedy(100,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_500 =  greedy.greedy_EGreedy(500,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_1000 =  greedy.greedy_EGreedy(1000,nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_10000 =  greedy.greedy_EGreedy(10000,nb_prop,nb_place,n_MAJ)

# %%
player_d_greedy_EGreedy_500_MAJ5  =  greedy.greedy_EGreedy(500,nb_prop,nb_place,5)
referee_greedy_EGreedy_500_5000trials_20games_desord_MAJ5 = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_greedy_EGreedy_500_5000trials_20games_desord_MAJ5 .play_game(player_d_greedy_EGreedy_500_MAJ5 )

end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 0min 13sec

# %% [markdown]
# ### Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_desord = Referee(env,nb_trial)
referee_Random_5000trials_20games_desord = Referee(env,nb_trial)

referee_greedy_EGreedy_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_50_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_100_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_500_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_1000_5000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_10000_5000trials_20games_desord = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_Oracle_5000trials_20games_desord.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_desord.play_game(player_d_Random)
    
    referee_greedy_EGreedy_10_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_10)
    referee_greedy_EGreedy_50_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_50)
    referee_greedy_EGreedy_100_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_100)
    referee_greedy_EGreedy_500_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_500)
    referee_greedy_EGreedy_1000_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_1000)
    referee_greedy_EGreedy_10000_5000trials_20games_desord.play_game(player_d_greedy_EGreedy_10000)

end = time.time()   
print ('time :',end-start)
# Out:
# time : 112.30048131942749

# %%
print (time_sec_to_HMS(112))
print(time_sec_to_HMS(201))
# Out:
# 0H 1min 52sec
# 0H 3min 21sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_greedy_EGreedy_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'b', label='greedy Egreedy,, c = 10')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_50_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'g', label='greedy Egreedy,, c = 50')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_100_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'purple', label='greedy Egreedy,, c = 100')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_500_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'black', label='greedy Egreedy,, c = 500')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_1000_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'brown', label='greedy Egreedy,, c = 1000')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_10000_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', label='greedy Egreedy,, c = 10000')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %%
def test_c_Egreedy(kappas, thetas,nb_game,c_list,n_MAJ = 1):
    nb_prop = len(thetas)  
    nb_place = len(kappas)
    env = Environment_PBM(thetas,kappas)

    #####Oracle + Randome
    player_Oracle = oracle.Oracle(env.get_best_index())
    player_Random = random_player.Random(nb_prop,nb_place)
    referee_Oracle_5000trials_20games = Referee(env,nb_trial)
    referee_Random_5000trials_20games = Referee(env,nb_trial)

    start = time.time()
  
    for i in range(nb_game):
        referee_Oracle_5000trials_20games.play_game(player_Oracle)
        referee_Random_5000trials_20games.play_game(player_Random)

    end = time.time()   
    print ('time_borne :',time_sec_to_HMS(end-start)) 
    ##### initie graph 
    trials = [i for i in range(referee_Oracle_5000trials_20games.nb_trials)]
    plt.figure(figsize=(10, 10))
    plt.plot(trials, np.cumsum(referee_Random_5000trials_20games.get_regret_expected(), axis=0)[trials],'r-', label='Random')

    ######Joues les différents egreedy
    
    start = time.time()
    for c in c_list:
        
        referee_EGreedy_5000trials_20games = Referee(env,nb_trial)

        start = time.time()
  
        for i in range(nb_game):
            player_EGreedy =  greedy.greedy_EGreedy(c,nb_prop,nb_place,n_MAJ)
            #print ("nb trial init =",player_EGreedy.nb_trials )
            #print ("thetas_pyclic init =",player_EGreedy.thetas_pyclic )
            referee_EGreedy_5000trials_20games .play_game(player_EGreedy)
            #print ("c =",c )
            #print ("i =",i )
            #print ("nb trial =",player_EGreedy.nb_trials )
            #print ("thetas_pyclic =",player_EGreedy.thetas_pyclic )

    
        ##### Add player perf
        plt.plot(trials, np.cumsum(referee_EGreedy_5000trials_20games.get_regret_expected(), axis=0)[trials], label='Egreedy, c = '+str(c) )
    end = time.time()   
    print ('time TEST egreedy with c = : ',time_sec_to_HMS(end-start)) 
    
    #### plot all graph

    plt.xlabel('Time')
    plt.ylabel('Cumulative Expected Regret')
    plt.title ('Test c of Egreedy on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials')
    plt.legend()
    plt.grid(True)
    plt.loglog()
    plt.show()

# %%
###player corrected hopefully
kappas_desord = [1,0.7,0.3,0.75,0.1]
thetas = [0.9,0.3,0.5,0.4,0.1,0.2,0.5,0.1,0.8,0.4]
c_list = [1, 5,10, 50,100,150, 1000,10000]
nb_game = 20
test_c_Egreedy(kappas_desord, thetas,nb_game,c_list,n_MAJ = 1)
# Out:
# time_borne : 0H 0min 5sec
# time TEST egreedy with c = :  0H 0min 17sec

# %%
kappas_desord = [1,0.7,0.3,0.75,0.1]
thetas = [0.9,0.3,0.5,0.4,0.1,0.2,0.5,0.1,0.8,0.4]
c_list = [1, 5,10, 50,100,150, 1000,10000]
nb_game = 20
test_c_Egreedy(kappas_desord, thetas,nb_game,c_list,n_MAJ = 1)
# Out:
# time_borne : 0H 0min 6sec
# time for egreedy with c = 1 :  0H 0min 37sec
# time for egreedy with c = 5 :  0H 0min 32sec
# time for egreedy with c = 10 :  0H 0min 34sec
# time for egreedy with c = 50 :  0H 0min 32sec
# time for egreedy with c = 100 :  0H 0min 35sec
# time for egreedy with c = 150 :  0H 0min 33sec
# time for egreedy with c = 1000 :  0H 0min 32sec
# time for egreedy with c = 10000 :  0H 0min 26sec

# %%
kappas_desord = [1,0.7,0.3,0.75,0.1]
thetas = [0.9,0.3,0.5,0.4,0.1,0.2,0.5,0.1,0.8,0.4]
nb_prop = len(thetas)  
nb_place = len(kappas_desord)

c_list = [1, 5,10, 50,100,150, 1000,10000]
env = Environment_PBM(thetas,kappas_desord)

#####Oracle + Randome
player_Oracle = oracle.Oracle(env.get_best_index())
player_Random = random_player.Random(nb_prop,nb_place)
referee_Oracle_5000trials_20games = Referee(env,nb_trial)
referee_Random_5000trials_20games = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_Oracle_5000trials_20games.play_game(player_Oracle)
    referee_Random_5000trials_20games.play_game(player_Random)

end = time.time()   
print ('time_borne :',time_sec_to_HMS(end-start)) 
##### initie graph 
trials = [i for i in range(referee_Oracle_5000trials_20games.nb_trials)]
plt.figure(figsize=(10, 10))
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games.get_regret_expected(), axis=0)[trials],'r-', label='Random')

######Joues les différents egreedy
n_MAJ = 1

for c in c_list:
    player_EGreedy =  greedy.greedy_EGreedy(c,nb_prop,nb_place,n_MAJ)
    referee_EGreedy_5000trials_20games = Referee(env,nb_trial)

    start = time.time()
  
    for i in range(nb_game):
    #print ('#### game '+str(i))
        referee_EGreedy_5000trials_20games .play_game(player_EGreedy )

    end = time.time()   
    print ('time for egreedy with c = '+str(c)+' : ',time_sec_to_HMS(end-start)) 
    
    ##### Add player perf
    plt.plot(trials, np.cumsum(referee_EGreedy_5000trials_20games.get_regret_expected(), axis=0)[trials], label='Egreedy, c = '+str(c) )

#### plot all graph

plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()
# Out:
# time_borne : 0H 0min 5sec
# time for egreedy with c = 1 :  0H 0min 44sec
# time for egreedy with c = 5 :  0H 0min 38sec
# time for egreedy with c = 10 :  0H 0min 39sec
# time for egreedy with c = 50 :  0H 0min 38sec
# time for egreedy with c = 100 :  0H 0min 42sec
# time for egreedy with c = 150 :  0H 0min 35sec
# time for egreedy with c = 1000 :  0H 0min 35sec
# time for egreedy with c = 10000 :  0H 0min 32sec

# %% [markdown]
# ### Game 20 Trial 10000

# %%
nb_trial = 10000
nb_game = 20

referee_Oracle_10000trials_20games_desord = Referee(env,nb_trial)
referee_Random_10000trials_20games_desord = Referee(env,nb_trial)

referee_greedy_EGreedy_10_10000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_50_10000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_70_10000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_100_10000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_500_10000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_1000_10000trials_20games_desord = Referee(env,nb_trial)
referee_greedy_EGreedy_10000_10000trials_20games_desord = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    referee_Oracle_10000trials_20games_desord.play_game(player_d_Oracle)
    referee_Random_10000trials_20games_desord.play_game(player_d_Random)
    
    referee_greedy_EGreedy_10_10000trials_20games_desord.play_game(player_d_greedy_EGreedy_10)
    referee_greedy_EGreedy_50_10000trials_20games_desord.play_game(player_d_greedy_EGreedy_50)
    referee_greedy_EGreedy_70_10000trials_20games_desord.play_game(player_d_greedy_EGreedy_70)
    referee_greedy_EGreedy_100_10000trials_20games_desord.play_game(player_d_greedy_EGreedy_100)
    referee_greedy_EGreedy_500_10000trials_20games_desord.play_game(player_d_greedy_EGreedy_500)
    referee_greedy_EGreedy_1000_10000trials_20games_desord.play_game(player_d_greedy_EGreedy_1000)
    referee_greedy_EGreedy_10000_10000trials_20games_desord.play_game(player_d_greedy_EGreedy_10000)

end = time.time()   
print ('time :',end-start)
# Out:
# time : 490.2467670440674

# %%
trials = [i for i in range(referee_Oracle_10000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_10000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_10000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_greedy_EGreedy_10_10000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'b', label='greedy Egreedy, c = 10')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_50_10000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'g', label='greedy Egreedy, c = 50')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_100_10000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'purple', label='greedy Egreedy, c = 100')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_500_10000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'black', label='greedy Egreedy, c = 500')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_1000_10000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'brown', label='greedy Egreedy, c = 1000')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_10000_10000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', label='greedy Egreedy, c = 10000')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_70_10000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange', label='greedy Egreedy, c = 70')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ## After Test Config

# %% [markdown]
# ### light kappa desorder

# %%
kappas_desord = [1,0.7,0.3,0.75,0.1]
kappas_desord_s = [1,0.3,0.6,0.75,0.1]
thetas = [0.9,0.3,0.5,0.4,0.1,0.2,0.5,0.1,0.8,0.4]
nb_prop = len(thetas)  
nb_place = len(kappas_desord)

# %%
pas = 10
env = Environment_PBM(thetas,kappas_desord)

part0 = [np.array([uniform(0, 1) for i  in range(nb_prop)]), np.array([1]+[uniform(0, 1) for i  in range(1,nb_place)])]
 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)

player_d_TSMH_base_1 =  TS_MH_with_effi(nb_prop,nb_place,part0,pas,1)
player_d_TSMH_base_100 =  TS_MH_with_effi(nb_prop,nb_place,part0,pas,100)
player_d_TSMH_kappa_desord_01 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas,0.1)
player_d_TSMH_kappa_desord_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas,1)

n_MAJ = 5
player_d_greedy = greedy.greedy(nb_prop,nb_place,n_MAJ)
player_d_greedy_EGreedy_100 =  greedy.greedy_EGreedy(100,nb_prop,nb_place,n_MAJ)


player_d_BC_MPTS_triche = bc_mpts.BC_MPTS_triche(nb_prop,nb_place,kappas_desord)
player_d_BC_MPTS_greedy = bc_mpts.BC_MPTS_greedy(nb_prop,nb_place,n_MAJ)

# %% [markdown]
# ### Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_afterconfig = Referee(env,nb_trial)
referee_Random_5000trials_20games_afterconfig = Referee(env,nb_trial)

referee_greedy_5000trials_20games_afterconfig  = Referee(env,nb_trial)
referee_greedy_EGreedy_100_5000trials_20games_afterconfig = Referee(env,nb_trial)

referee_BC_MPTS_triche_5000trials_20games_afterconfig  = Referee(env,nb_trial)
referee_BC_MPTS_greedy_5000trials_20games_afterconfig = Referee(env,nb_trial)

referee_TSMH_base_1_5000trials_20games_afterconfig  = Referee(env,nb_trial)
referee_TSMH_kappa_desord_1_5000trials_20games_afterconfig  = Referee(env,nb_trial)
referee_TSMH_base_100_5000trials_20games_afterconfig  = Referee(env,nb_trial)
referee_TSMH_kappa_desord_01_5000trials_20games_afterconfig  = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    n_MAJ = 1
    player_d_greedy = greedy.greedy(nb_prop,nb_place,n_MAJ)
    player_d_greedy_EGreedy_100 =  greedy.greedy_EGreedy(100,nb_prop,nb_place,n_MAJ)


    player_d_BC_MPTS_triche = bc_mpts.BC_MPTS_triche(nb_prop,nb_place,kappas_desord)
    player_d_BC_MPTS_greedy = bc_mpts.BC_MPTS_greedy(nb_prop,nb_place,n_MAJ)  
    
    referee_Oracle_5000trials_20games_afterconfig.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_afterconfig.play_game(player_d_Random)
    
    referee_greedy_5000trials_20games_afterconfig.play_game(player_d_greedy)
    referee_greedy_EGreedy_100_5000trials_20games_afterconfig.play_game(player_d_greedy_EGreedy_100)
    
    referee_BC_MPTS_triche_5000trials_20games_afterconfig.play_game(player_d_BC_MPTS_triche)
    referee_BC_MPTS_greedy_5000trials_20games_afterconfig.play_game(player_d_BC_MPTS_greedy)

end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 1min 53sec

# %%
start = time.time()
for i in range(nb_game):
    print ('#### game '+str(i))   
    start_game = time.time()
    
    player_d_TSMH_kappa_desord_01 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,0.1)
    player_d_TSMH_kappa_desord_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1)
    
    referee_TSMH_kappa_desord_1_5000trials_20games_afterconfig.play_game(player_d_TSMH_kappa_desord_1)
    referee_TSMH_kappa_desord_01_5000trials_20games_afterconfig.play_game(player_d_TSMH_kappa_desord_01)
    end_game = time.time()
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 36min 39sec
# #### game 1
# time_game : 0H 2min 54sec
# #### game 2
# time_game : 0H 3min 9sec
# #### game 3
# time_game : 0H 3min 9sec
# #### game 4
# time_game : 0H 3min 5sec
# #### game 5
# time_game : 0H 3min 44sec
# #### game 6
# time_game : 0H 3min 34sec
# #### game 7
# time_game : 0H 3min 44sec
# #### game 8
# time_game : 0H 3min 36sec
# #### game 9
# time_game : 0H 3min 8sec
# #### game 10
# time_game : 0H 3min 44sec
# #### game 11
# time_game : 0H 4min 9sec
# #### game 12
# time_game : 0H 4min 16sec
# #### game 13
# time_game : 0H 4min 34sec
# #### game 14
# time_game : 0H 4min 58sec
# #### game 15
# time_game : 0H 4min 27sec
# #### game 16
# time_game : 0H 4min 10sec
# #### game 17
# time_game : 0H 4min 18sec
# #### game 18
# time_game : 0H 4min 43sec
# #### game 19
# time_game : 0H 5min 6sec
# time : 1H 51min 14sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_afterconfig.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_greedy_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials],'orange', label='greedy')
plt.plot(trials, np.cumsum(referee_greedy_EGreedy_100_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials],color='tomato', label='greedy Egreedy, c = 100')

plt.plot(trials, np.cumsum(referee_BC_MPTS_triche_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials],'g-', label='BC_MPTS_triche')
plt.plot(trials, np.cumsum(referee_BC_MPTS_greedy_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials],'g--' ,label='BC_MPTS_greedy')

#plt.plot(trials, np.cumsum(referee_TSMH_base_1_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = 'solid', label='TSMH_base, c = 1')
#plt.plot(trials, np.cumsum(referee_TSMH_base_100_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials],'b-', label='TSMH_base, c = 100')

plt.plot(trials, np.cumsum(referee_TSMH_kappa_desord_1_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = '--', label='TSMH_kappa_desord, c =1')
plt.plot(trials, np.cumsum(referee_TSMH_kappa_desord_01_5000trials_20games_afterconfig.get_regret_expected(), axis=0)[trials],'b--', label='TSMH_kappa_desord, c = 0.1')

plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ### write logs

# %%
pwd
# Out:
# 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank\\Test\\interaction'

# %%
cd result/eval_opponents/kappa_light_afterconfig/
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\eval_opponents\kappa_light_afterconfig

# %%
with open('referee_Oracle_5000trials_20games_afterconfig.txt', 'w') as file:
    json.dump(referee_Oracle_5000trials_20games_afterconfig.record_results, file)
with open('referee_Random_5000trials_20games_afterconfig.txt', 'w') as file:
    json.dump(referee_Random_5000trials_20games_afterconfig.record_results, file)
    
with open('referee_greedy_5000trials_20games_afterconfig.txt', 'w') as file:
    json.dump(referee_greedy_5000trials_20games_afterconfig.record_results, file)
with open('referee_greedy_EGreedy_100_5000trials_20games_afterconfig.txt', 'w') as file:
    json.dump(referee_greedy_EGreedy_100_5000trials_20games_afterconfig.record_results, file)

with open('referee_BC_MPTS_triche_5000trials_20games_afterconfig.txt', 'w') as file:
    json.dump(referee_BC_MPTS_triche_5000trials_20games_afterconfig.record_results, file)    
with open('referee_BC_MPTS_greedy_5000trials_20games_afterconfig.txt', 'w') as file:
    json.dump(referee_BC_MPTS_greedy_5000trials_20games_afterconfig.record_results, file)
    
with open('referee_TSMH_kappa_desord_1_5000trials_20games_afterconfig.txt', 'w') as file:
    json.dump(referee_TSMH_kappa_desord_1_5000trials_20games_afterconfig.record_results, file)
with open('referee_TSMH_kappa_desord_01_5000trials_20games_afterconfig.txt', 'w') as file:
    json.dump(referee_TSMH_kappa_desord_01_5000trials_20games_afterconfig.record_results, file)
