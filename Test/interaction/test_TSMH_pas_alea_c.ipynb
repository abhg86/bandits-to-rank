# %% [markdown]
# ## Test TSHM pas, part alea, c

# %%
import sys
sys.path.insert(0, 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank')

# %%
from bandits_to_rank.bandits import *
from bandits_to_rank.environment import *
from bandits_to_rank.referee import *
from bandits_to_rank.opponents import oracle,random_player,greedy,bc_mpts

import time
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import floor, log
from random import shuffle
from copy import deepcopy


# %reload_ext autoreload
# %autoreload 2

# %%
def time_sec_to_HMS(sec):
    heure=sec//3600
    rest_h=sec%3600
    minute=rest_h//60
    rest_m=rest_h%60

    return(str(int(heure))+'H '+str(int(minute))+'min '+str(int(rest_m))+'sec')

# %% [markdown]
# ## Tests TSMH c + pas

# %%
kappas_desord = [1,0.3,0.6,0.75,0.1]
thetas = [0.9,0.3,0.5,0.4,0.1,0.2,0.5,0.1,0.8,0.4]
nb_prop = len(thetas)  
nb_place = len(kappas_desord)

# %%
pas = 10
c = [0.1, 1, 10, 100, 1000, 10000]
pas = [10, 5, 1]
env = Environment_PBM(thetas,kappas_desord)

part0 = [np.array([uniform(0, 1) for i  in range(nb_prop)]), np.array([1]+[uniform(0, 1) for i  in range(1,nb_place)])]
 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)

player_d_TSMH_c_01_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,0.1)
player_d_TSMH_c_1_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1)
player_d_TSMH_c_10_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10)
player_d_TSMH_c_100_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,100)
player_d_TSMH_c_1000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1000)
player_d_TSMH_c_10000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10000)

player_d_TSMH_c_01_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,0.1)
player_d_TSMH_c_1_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1)
player_d_TSMH_c_10_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10)
player_d_TSMH_c_100_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,100)
player_d_TSMH_c_1000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1000)
player_d_TSMH_c_10000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10000)

player_d_TSMH_c_01_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,0.1)
player_d_TSMH_c_1_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1)
player_d_TSMH_c_10_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10)
player_d_TSMH_c_100_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,100)
player_d_TSMH_c_1000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1000)
player_d_TSMH_c_10000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10000)

# %% [markdown]
# ### Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_desord = Referee(env,nb_trial)
referee_Random_5000trials_20games_desord = Referee(env,nb_trial)


referee_TSMH_c_01_pas_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_1_pas_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_10_pas_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_100_pas_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_10000_pas_10_5000trials_20games_desord = Referee(env,nb_trial)


referee_TSMH_c_01_pas_5_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_1_pas_5_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_10_pas_5_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_100_pas_5_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_5_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_10000_pas_5_5000trials_20games_desord = Referee(env,nb_trial)


referee_TSMH_c_01_pas_1_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_1_pas_1_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_10_pas_1_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_100_pas_1_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_1_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_c_10000_pas_1_5000trials_20games_desord = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    
    player_d_TSMH_c_01_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,0.1)
    player_d_TSMH_c_1_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1)
    player_d_TSMH_c_10_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10)
    player_d_TSMH_c_100_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,100)
    player_d_TSMH_c_1000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1000)
    player_d_TSMH_c_10000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10000)

    referee_Oracle_5000trials_20games_desord.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_desord.play_game(player_d_Random)

    referee_TSMH_c_01_pas_10_5000trials_20games_desord.play_game(player_d_TSMH_c_01_pas_10)
    referee_TSMH_c_1_pas_10_5000trials_20games_desord.play_game(player_d_TSMH_c_1_pas_10)
    referee_TSMH_c_10_pas_10_5000trials_20games_desord.play_game(player_d_TSMH_c_10_pas_10)
    referee_TSMH_c_100_pas_10_5000trials_20games_desord.play_game(player_d_TSMH_c_100_pas_10)
    referee_TSMH_c_1000_pas_10_5000trials_20games_desord.play_game(player_d_TSMH_c_1000_pas_10)
    referee_TSMH_c_10000_pas_10_5000trials_20games_desord.play_game(player_d_TSMH_c_10000_pas_10)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 5min 1sec
# #### game 1
# time_game : 0H 5min 3sec
# #### game 2
# time_game : 0H 5min 1sec
# #### game 3
# time_game : 0H 4min 59sec
# #### game 4
# time_game : 0H 5min 11sec
# #### game 5
# time_game : 0H 5min 4sec
# #### game 6
# time_game : 0H 4min 59sec
# #### game 7
# time_game : 0H 5min 1sec
# #### game 8
# time_game : 0H 5min 0sec
# #### game 9
# time_game : 0H 4min 57sec
# #### game 10
# time_game : 0H 4min 57sec
# #### game 11
# time_game : 0H 5min 3sec
# #### game 12
# time_game : 0H 5min 3sec
# #### game 13
# time_game : 0H 5min 2sec
# #### game 14
# time_game : 0H 5min 0sec
# #### game 15
# time_game : 0H 5min 1sec
# #### game 16
# time_game : 0H 4min 56sec
# #### game 17
# time_game : 0H 5min 0sec
# #### game 18
# time_game : 0H 5min 1sec
# #### game 19
# time_game : 0H 4min 59sec
# time : 1H 40min 28sec

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    
  
    player_d_TSMH_c_01_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,0.1)
    player_d_TSMH_c_1_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1)
    player_d_TSMH_c_10_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10)
    player_d_TSMH_c_100_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,100)
    player_d_TSMH_c_1000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1000)
    player_d_TSMH_c_10000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10000)


    referee_TSMH_c_01_pas_5_5000trials_20games_desord.play_game(player_d_TSMH_c_01_pas_5)
    referee_TSMH_c_1_pas_5_5000trials_20games_desord.play_game(player_d_TSMH_c_1_pas_5)
    referee_TSMH_c_10_pas_5_5000trials_20games_desord.play_game(player_d_TSMH_c_10_pas_5)
    referee_TSMH_c_100_pas_5_5000trials_20games_desord.play_game(player_d_TSMH_c_100_pas_5)
    referee_TSMH_c_1000_pas_5_5000trials_20games_desord.play_game(player_d_TSMH_c_1000_pas_5)
    referee_TSMH_c_10000_pas_5_5000trials_20games_desord.play_game(player_d_TSMH_c_10000_pas_5)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 3min 58sec
# #### game 1
# time_game : 0H 2min 34sec
# #### game 2
# time_game : 0H 2min 24sec
# #### game 3
# time_game : 0H 2min 24sec
# #### game 4
# time_game : 0H 2min 25sec
# #### game 5
# time_game : 0H 2min 26sec
# #### game 6
# time_game : 0H 2min 28sec
# #### game 7
# time_game : 0H 2min 29sec
# #### game 8
# time_game : 0H 2min 28sec
# #### game 9
# time_game : 0H 2min 27sec
# #### game 10
# time_game : 0H 2min 30sec
# #### game 11
# time_game : 0H 2min 29sec
# #### game 12
# time_game : 0H 2min 26sec
# #### game 13
# time_game : 0H 2min 29sec
# #### game 14
# time_game : 0H 2min 29sec
# #### game 15
# time_game : 0H 2min 27sec
# #### game 16
# time_game : 0H 2min 28sec
# #### game 17
# time_game : 0H 2min 28sec
# #### game 18
# time_game : 0H 2min 27sec
# #### game 19
# time_game : 0H 2min 28sec
# time : 0H 50min 54sec

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
  
    player_d_TSMH_c_01_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,0.1)
    player_d_TSMH_c_1_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1)
    player_d_TSMH_c_10_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10)
    player_d_TSMH_c_100_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,100)
    player_d_TSMH_c_1000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1000)
    player_d_TSMH_c_10000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10000)
    
    referee_TSMH_c_01_pas_1_5000trials_20games_desord.play_game(player_d_TSMH_c_01_pas_1)
    referee_TSMH_c_1_pas_1_5000trials_20games_desord.play_game(player_d_TSMH_c_1_pas_1)
    referee_TSMH_c_10_pas_1_5000trials_20games_desord.play_game(player_d_TSMH_c_10_pas_1)
    referee_TSMH_c_100_pas_1_5000trials_20games_desord.play_game(player_d_TSMH_c_100_pas_1)
    referee_TSMH_c_1000_pas_1_5000trials_20games_desord.play_game(player_d_TSMH_c_1000_pas_1)
    referee_TSMH_c_10000_pas_1_5000trials_20games_desord.play_game(player_d_TSMH_c_10000_pas_1)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 0min 47sec
# #### game 1
# time_game : 0H 0min 48sec
# #### game 2
# time_game : 0H 0min 45sec
# #### game 3
# time_game : 0H 0min 43sec
# #### game 4
# time_game : 0H 0min 42sec
# #### game 5
# time_game : 0H 0min 41sec
# #### game 6
# time_game : 0H 0min 41sec
# #### game 7
# time_game : 0H 0min 42sec
# #### game 8
# time_game : 0H 0min 42sec
# #### game 9
# time_game : 0H 0min 44sec
# #### game 10
# time_game : 0H 0min 44sec
# #### game 11
# time_game : 0H 0min 44sec
# #### game 12
# time_game : 0H 0min 44sec
# #### game 13
# time_game : 0H 0min 43sec
# #### game 14
# time_game : 0H 0min 43sec
# #### game 15
# time_game : 0H 0min 41sec
# #### game 16
# time_game : 0H 0min 42sec
# #### game 17
# time_game : 0H 0min 43sec
# #### game 18
# time_game : 0H 0min 42sec
# #### game 19
# time_game : 0H 0min 43sec
# time : 0H 14min 35sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'b-', label='TSHM, c = 0.1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'b--', label='TSHM, c = 0.1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'b:', label='TSHM, c = 0.1, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'g-', label='TSHM, c = 1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'g--', label='TSHM, c = 1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'g:', label='TSHM, c = 1, steps= 1')


plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = 'solid', label='TSHM, c = 10, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = '--', label='TSHM, c = 10, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = ':', label='TSHM, c = 10, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = 'solid', label='TSHM, c = 100, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = '--', label='TSHM, c = 100, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = ':', label='TSHM, c = 100, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = 'solid', label='TSHM, c = 1000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = '--', label='TSHM, c = 1000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = ':', label='TSHM, c = 1000, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = 'solid', label='TSHM, c = 10000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = '--', label='TSHM, c = 10000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = ':', label='TSHM, c = 10000, steps= 1')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()




trials = [i for i in range(referee_Oracle_5000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'b-', label='TSHM, c = 0.1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'b--', label='TSHM, c = 0.1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'b:', label='TSHM, c = 0.1, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'g-', label='TSHM, c = 1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'g:', label='TSHM, c = 1, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = 'solid', label='TSHM, c = 10, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = 'solid', label='TSHM, c = 100, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = 'solid', label='TSHM, c = 1000, steps= 10')

plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = 'solid', label='TSHM, c = 10000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = '--', label='TSHM, c = 10000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = ':', label='TSHM, c = 10000, steps= 1')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ### write logs

# %%
pwd
# Out:
# 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank\\Test\\interaction\\result\\eval_TSMH_pas_c_alea\\pasXc'

# %%
cd ..
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\eval_TSMH_pas_c_alea

# %%
cd result/eval_TSMH_pas_c_alea/pasXc/v_7_11_19
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\eval_TSMH_pas_c_alea\pasXc\v_7_11_19

# %%
with open('referee_Oracle_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_Oracle_5000trials_20games_desord.record_results, file)
with open('referee_Random_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_Random_5000trials_20games_desord.record_results, file)
    
with open('referee_TSMH_c_01_pas_10_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_10_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_1_pas_10_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_10_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_10_pas_10_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_10_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_100_pas_10_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_10_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_1000_pas_10_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_10_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_10000_pas_10_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_10_5000trials_20games_desord.record_results, file)
    
with open('referee_TSMH_c_01_pas_5_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_5_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_1_pas_5_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_5_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_10_pas_5_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_5_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_100_pas_5_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_5_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_1000_pas_5_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_5_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_10000_pas_5_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_5_5000trials_20games_desord.record_results, file)
    
    

with open('referee_TSMH_c_01_pas_1_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_1_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_1_pas_1_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_1_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_10_pas_1_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_1_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_100_pas_1_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_1_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_1000_pas_1_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_1_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_c_10000_pas_1_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_1_5000trials_20games_desord.record_results, file)

# %%
cd..
cd v_6_11_19

# %%
with open('referee_TSMH_c_01_pas_10_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_01_pas_10_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_1_pas_10_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_1_pas_10_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_10_pas_10_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_10_pas_10_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_100_pas_10_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_100_pas_10_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_1000_pas_10_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_1000_pas_10_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_10000_pas_10_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_10000_pas_10_5000trials_20games_desord = json.load(file)
        
with open('referee_TSMH_c_01_pas_5_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_01_pas_5_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_1_pas_5_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_1_pas_5_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_10_pas_5_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_10_pas_5_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_100_pas_5_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_100_pas_5_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_1000_pas_5_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_1000_pas_5_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_10000_pas_5_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_10000_pas_5_5000trials_20games_desord = json.load(file)

with open('referee_TSMH_c_01_pas_1_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_01_pas_1_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_1_pas_1_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_1_pas_1_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_10_pas_1_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_10_pas_1_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_100_pas_1_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_100_pas_1_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_1000_pas_1_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_1000_pas_1_5000trials_20games_desord = json.load(file)
with open('referee_TSMH_c_10000_pas_1_5000trials_20games_desord.txt', 'r') as file:
    read_referee_TSMH_c_10000_pas_1_5000trials_20games_desord = json.load(file)

# %%
def get_regret_expected_dico(dico):
    expec_best = np.mean(dico['expected_best_reward'],axis =0)
    expec_prop = np.mean(dico['expected_reward'],axis =0)
    return expec_best - expec_prop

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_01_pas_10_5000trials_20games_desord), axis=0)[trials],'b-', label='TSHM, c = 0.1, steps= 10')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_01_pas_5_5000trials_20games_desord), axis=0)[trials],'b--', label='TSHM, c = 0.1, steps= 5')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_01_pas_1_5000trials_20games_desord), axis=0)[trials],'b:', label='TSHM, c = 0.1, steps= 1')

plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_1_pas_10_5000trials_20games_desord), axis=0)[trials],'g-', label='TSHM, c = 1, steps= 10')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_1_pas_5_5000trials_20games_desord), axis=0)[trials],'g--', label='TSHM, c = 1, steps= 5')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_1_pas_1_5000trials_20games_desord), axis=0)[trials],'g:', label='TSHM, c = 1, steps= 1')


plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_10_pas_10_5000trials_20games_desord), axis=0)[trials], color = 'orange', linestyle = 'solid', label='TSHM, c = 10, steps= 10')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_10_pas_5_5000trials_20games_desord), axis=0)[trials], color = 'orange', linestyle = '--', label='TSHM, c = 10, steps= 5')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_10_pas_1_5000trials_20games_desord), axis=0)[trials], color = 'orange', linestyle = ':', label='TSHM, c = 10, steps= 1')

plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_100_pas_10_5000trials_20games_desord), axis=0)[trials], color = 'black', linestyle = 'solid', label='TSHM, c = 100, steps= 10')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_100_pas_5_5000trials_20games_desord), axis=0)[trials], color = 'black', linestyle = '--', label='TSHM, c = 100, steps= 5')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_100_pas_1_5000trials_20games_desord), axis=0)[trials], color = 'black', linestyle = ':', label='TSHM, c = 100, steps= 1')

plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_1000_pas_10_5000trials_20games_desord), axis=0)[trials], color = 'purple', linestyle = 'solid', label='TSHM, c = 1000, steps= 10')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_1000_pas_5_5000trials_20games_desord), axis=0)[trials], color = 'purple', linestyle = '--', label='TSHM, c = 1000, steps= 5')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_1000_pas_1_5000trials_20games_desord), axis=0)[trials], color = 'purple', linestyle = ':', label='TSHM, c = 1000, steps= 1')

plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_10000_pas_10_5000trials_20games_desord), axis=0)[trials], color = 'pink', linestyle = 'solid', label='TSHM, c = 10000, steps= 10')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_10000_pas_5_5000trials_20games_desord), axis=0)[trials], color = 'pink', linestyle = '--', label='TSHM, c = 10000, steps= 5')
plt.plot(trials, np.cumsum(get_regret_expected_dico(read_referee_TSMH_c_10000_pas_1_5000trials_20games_desord), axis=0)[trials], color = 'pink', linestyle = ':', label='TSHM, c = 10000, steps= 1')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ## Tests TSMH pas + alea

# %%
kappas_desord = [1,0.3,0.6,0.75,0.1]
thetas = [0.9,0.3,0.5,0.4,0.1,0.2,0.5,0.1,0.8,0.4]
nb_prop = len(thetas)  
nb_place = len(kappas_desord)

# %%
pas = 10
c = 1
pas = [10, 5, 1]
env = Environment_PBM(thetas,kappas_desord)

part0 = [np.array([uniform(0, 1) for i  in range(nb_prop)]), np.array([1]+[uniform(0, 1) for i  in range(1,nb_place)])]
 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)

player_TSMH_pas_10_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1,part_suivie=False)

player_TSMH_pas_5_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=5,c=1,part_suivie= False)

player_TSMH_pas_1_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1,part_suivie=False)

# %% [markdown]
# ### Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_desord = Referee(env,nb_trial)
referee_Random_5000trials_20games_desord = Referee(env,nb_trial)


referee_TSMH_pas_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_pas_5_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_pas_1_5000trials_20games_desord = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    referee_Oracle_5000trials_20games_desord.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_desord.play_game(player_d_Random)
    
    ### Reboot players
    player_TSMH_pas_10_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1,part_suivie=False)

    player_TSMH_pas_5_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=5,c=1,part_suivie= False)

    player_TSMH_pas_1_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1,part_suivie=False)

    ### play game
    referee_TSMH_pas_10_5000trials_20games_desord.play_game(player_TSMH_pas_10_partalea)
    referee_TSMH_pas_5_5000trials_20games_desord.play_game(player_TSMH_pas_5_partalea)
    referee_TSMH_pas_1_5000trials_20games_desord.play_game(player_TSMH_pas_1_partalea)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 5min 12sec
# #### game 1
# time_game : 0H 4min 57sec
# #### game 2
# time_game : 0H 4min 11sec
# #### game 3
# time_game : 0H 3min 55sec
# #### game 4
# time_game : 0H 3min 29sec
# #### game 5
# time_game : 0H 3min 29sec
# #### game 6
# time_game : 0H 3min 43sec
# #### game 7
# time_game : 0H 3min 26sec
# #### game 8
# time_game : 0H 3min 26sec
# #### game 9
# time_game : 0H 3min 24sec
# #### game 10
# time_game : 0H 3min 25sec
# #### game 11
# time_game : 0H 3min 32sec
# #### game 12
# time_game : 0H 4min 39sec
# #### game 13
# time_game : 0H 4min 28sec
# #### game 14
# time_game : 0H 4min 27sec
# #### game 15
# time_game : 0H 4min 37sec
# #### game 16
# time_game : 0H 4min 51sec
# #### game 17
# time_game : 0H 4min 30sec
# #### game 18
# time_game : 0H 4min 26sec
# #### game 19
# time_game : 0H 4min 25sec
# time : 1H 22min 43sec

# %%
referee_TSMH_pas_100_5000trials_10games_desord = Referee(env,nb_trial)

start = time.time()
  
for i in range(10):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_100_partalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=100,c=1,part_suivie=False)
    ### play game
    referee_TSMH_pas_100_5000trials_10games_desord.play_game(player_TSMH_pas_100_partalea)

    end_game = time.time()   
    print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0time_game : 0H 26min 16sec
# #### game 1time_game : 0H 24min 43sec
# #### game 2time_game : 0H 24min 19sec
# #### game 3time_game : 0H 24min 1sec
# #### game 4time_game : 0H 22min 33sec
# #### game 5time_game : 0H 20min 46sec
# #### game 6time_game : 0H 21min 11sec
# #### game 7time_game : 0H 20min 48sec
# #### game 8time_game : 0H 21min 0sec
# #### game 9time_game : 0H 20min 19sec
# time : 3H 46min 1sec

# %%
referee_TSMH_pas_100_nonalea_5000trials_10games_desord = Referee(env,nb_trial)

start = time.time()
  
for i in range(10):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_100_partnonalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=100,c=1,part_suivie=True)
    ### play game
    referee_TSMH_pas_100_nonalea_5000trials_10games_desord.play_game(player_TSMH_pas_100_partnonalea)

    end_game = time.time()   
    print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0time_game : 0H 18min 3sec
# #### game 1time_game : 0H 20min 26sec
# #### game 2time_game : 0H 17min 7sec
# #### game 3time_game : 0H 17min 14sec
# #### game 4time_game : 1H 5min 43sec
# #### game 5time_game : 0H 24min 53sec
# #### game 6time_game : 0H 21min 43sec
# #### game 7time_game : 0H 20min 15sec
# #### game 8time_game : 3H 36min 28sec
# #### game 9time_game : 0H 23min 5sec
# time : 7H 25min 3sec

# %%
referee_TSMH_pas_1_nonalea_5000trials_20games = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_1_nonalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1)
    ###Play game
    referee_TSMH_pas_1_nonalea_5000trials_20games.play_game(player_TSMH_pas_1_nonalea)

    end_game = time.time()   
    #print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 6min 8sec

# %%
referee_TSMH_pas_10_nonalea_5000trials_20games = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_10_nonalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1)
    ###Play game
    referee_TSMH_pas_10_nonalea_5000trials_20games.play_game(player_TSMH_pas_10_nonalea)

    end_game = time.time()   
    print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0time_game : 0H 2min 59sec
# #### game 1time_game : 0H 3min 6sec
# #### game 2time_game : 0H 3min 6sec
# #### game 3time_game : 0H 3min 9sec
# #### game 4time_game : 0H 3min 7sec
# #### game 5time_game : 0H 3min 15sec
# #### game 6time_game : 0H 3min 11sec
# #### game 7time_game : 0H 33min 50sec
# #### game 8time_game : 0H 2min 58sec
# #### game 9time_game : 0H 3min 0sec
# #### game 10time_game : 0H 3min 19sec
# #### game 11time_game : 0H 3min 13sec
# #### game 12time_game : 0H 3min 22sec
# #### game 13time_game : 0H 3min 12sec
# #### game 14time_game : 0H 3min 8sec
# #### game 15time_game : 0H 3min 9sec
# #### game 16time_game : 0H 3min 5sec
# #### game 17time_game : 0H 3min 8sec
# #### game 18time_game : 0H 3min 6sec
# #### game 19time_game : 0H 3min 8sec
# time : 1H 33min 39sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_TSMH_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'b-', label='TSHM, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'g-', label='TSHM,  steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],color='purple', label='TSHM,  steps= 1')
plt.plot(trials, np.cumsum(referee_TSMH_pas_100_5000trials_10games_desord.get_regret_expected(), axis=0)[trials],color='orange', label='TSHM,  steps= 100')
plt.plot(trials, np.cumsum(referee_TSMH_pas_1_nonalea_5000trials_20games.get_regret_expected(), axis=0)[trials],color='purple',linestyle='--', label='TSHM,  steps= 1 particule suivie')
plt.plot(trials, np.cumsum(referee_TSMH_pas_10_nonalea_5000trials_20games.get_regret_expected(), axis=0)[trials],color='b',linestyle='--', label='TSHM,  steps= 10 particule suivie')
plt.plot(trials, np.cumsum(referee_TSMH_pas_100_nonalea_5000trials_10games_desord.get_regret_expected(), axis=0)[trials],color='orange',linestyle='--', label='TSHM,  steps= 10 particule suivie')



plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ### write logs

# %%
pwd
# Out:
# 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank\\Test\\interaction'

# %%
cd result\eval_TSMH_pas_c_alea\pasXalea
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\eval_TSMH_pas_c_alea\pasXalea

# %%
with open('referee_Oracle_5000trials_20games.txt', 'w') as file:
    json.dump(referee_Oracle_5000trials_20games_desord.record_results, file)
with open('referee_Random_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_Random_5000trials_20games_desord.record_results, file)
    
with open('referee_TSMH_partalea_pas_10_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_pas_10_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_partalea_pas_5_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_pas_5_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_partalea_pas_1_5000trials_20games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_pas_1_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_partalea_pas_100_5000trials_10games_desord.txt', 'w') as file:
    json.dump(referee_TSMH_pas_100_5000trials_10games_desord.record_results, file)
    
    
with open('referee_TSMH_pas_1_nonalea_5000trials_20games.txt', 'w') as file:
    json.dump(referee_TSMH_pas_1_nonalea_5000trials_20games.record_results, file)
with open('referee_TSMH_pas_10_nonalea_5000trials_20games.txt', 'w') as file:
    json.dump(referee_TSMH_pas_10_nonalea_5000trials_20games.record_results, file)
with open('referee_TSMH_pas_100_nonalea_5000trials_20games.txt', 'w') as file:
    json.dump(referee_TSMH_pas_100_nonalea_5000trials_20games.record_results, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-9fed1609157c> in <module>
#      21     json.dump(referee_TSMH_pas_10_nonalea_5000trials_20games.record_results, file)
#      22 with open('referee_TSMH_pas_100_nonalea_5000trials_20games.txt', 'w') as file:
# ---> 23     json.dump(referee_TSMH_pas_100_nonalea_5000trials_20games.record_results, file)
#
# NameError: name 'referee_TSMH_pas_100_nonalea_5000trials_20games' is not defined
