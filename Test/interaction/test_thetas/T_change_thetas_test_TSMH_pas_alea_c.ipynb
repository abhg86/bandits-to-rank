# %% [markdown]
# ## Thetas  realistic Test TSHM pas, part alea, c

# %%
import sys
sys.path.insert(0, 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank')

# %%
from bandits_to_rank.bandits import *
from bandits_to_rank.environment import *
from bandits_to_rank.referee import *
from bandits_to_rank.opponents import oracle,random_player,greedy,bc_mpts

import time
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import floor, log
from random import shuffle
from copy import deepcopy


# %reload_ext autoreload
# %autoreload 2

# %%
def time_sec_to_HMS(sec):
    heure=sec//3600
    rest_h=sec%3600
    minute=rest_h//60
    rest_m=rest_h%60

    return(str(int(heure))+'H '+str(int(minute))+'min '+str(int(rest_m))+'sec')

# %% [markdown]
# # Theta_final

# %% [markdown]
# ## Tests TSMH c + pas

# %%
kappas_desord = [1,0.3,0.6,0.75,0.1]
thetas_final =  [0.3,0.2,0.15,0.15,0.15,0.10,0.05,0.05,0.01,0.01]
nb_prop = len(thetas_final)  
nb_place = len(kappas_desord)

# %%
pas = 10
c = [0.1, 1, 10, 100, 1000, 10000]
pas = [10, 5, 1]
env = Environment_PBM(thetas_final,kappas_desord)

part0 = [np.array([uniform(0, 1) for i  in range(nb_prop)]), np.array([1]+[uniform(0, 1) for i  in range(1,nb_place)])]
 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)

player_d_TSMH_c_01_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,0.1)
player_d_TSMH_c_1_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1)
player_d_TSMH_c_10_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10)
player_d_TSMH_c_100_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,100)
player_d_TSMH_c_1000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1000)
player_d_TSMH_c_10000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10000)

player_d_TSMH_c_01_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,0.1)
player_d_TSMH_c_1_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1)
player_d_TSMH_c_10_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10)
player_d_TSMH_c_100_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,100)
player_d_TSMH_c_1000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1000)
player_d_TSMH_c_10000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10000)

player_d_TSMH_c_01_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,0.1)
player_d_TSMH_c_1_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1)
player_d_TSMH_c_10_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10)
player_d_TSMH_c_100_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,100)
player_d_TSMH_c_1000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1000)
player_d_TSMH_c_10000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10000)

# %%
env.thetas
# Out:
# [0.3, 0.2, 0.15, 0.15, 0.15, 0.1, 0.05, 0.05, 0.01, 0.01]

# %% [markdown]
# ## Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_Random_5000trials_20games_thetas_final = Referee(env,nb_trial)


referee_TSMH_c_01_pas_10_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_1_pas_10_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_10_pas_10_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_100_pas_10_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_10_5000trials_20games_thetas_final= Referee(env,nb_trial)
referee_TSMH_c_10000_pas_10_5000trials_20games_thetas_final = Referee(env,nb_trial)


referee_TSMH_c_01_pas_5_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_1_pas_5_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_10_pas_5_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_100_pas_5_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_5_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_10000_pas_5_5000trials_20games_thetas_final = Referee(env,nb_trial)


referee_TSMH_c_01_pas_1_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_1_pas_1_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_10_pas_1_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_100_pas_1_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_1_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_TSMH_c_10000_pas_1_5000trials_20games_thetas_final = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    referee_Oracle_5000trials_20games_thetas_final.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_thetas_final.play_game(player_d_Random)
    
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 0min 6sec

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
  
    player_d_TSMH_c_01_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,0.1)
    player_d_TSMH_c_1_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1)
    player_d_TSMH_c_10_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10)
    player_d_TSMH_c_100_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,100)
    player_d_TSMH_c_1000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1000)
    player_d_TSMH_c_10000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10000)
    
    referee_TSMH_c_01_pas_1_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_01_pas_1)
    referee_TSMH_c_1_pas_1_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_1_pas_1)
    referee_TSMH_c_10_pas_1_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_10_pas_1)
    referee_TSMH_c_100_pas_1_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_100_pas_1)
    referee_TSMH_c_1000_pas_1_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_1000_pas_1)
    referee_TSMH_c_10000_pas_1_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_10000_pas_1)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 0min 51sec
# #### game 1
# time_game : 0H 0min 49sec
# #### game 2
# time_game : 0H 0min 47sec
# #### game 3
# time_game : 0H 0min 48sec
# #### game 4
# time_game : 0H 0min 49sec
# #### game 5
# time_game : 0H 0min 50sec
# #### game 6
# time_game : 0H 0min 51sec
# #### game 7
# time_game : 0H 0min 49sec
# #### game 8
# time_game : 0H 0min 49sec
# #### game 9
# time_game : 0H 0min 50sec
# #### game 10
# time_game : 0H 0min 51sec
# #### game 11
# time_game : 0H 0min 55sec
# #### game 12
# time_game : 0H 0min 51sec
# #### game 13
# time_game : 0H 0min 50sec
# #### game 14
# time_game : 0H 0min 51sec
# #### game 15
# time_game : 0H 0min 52sec
# #### game 16
# time_game : 0H 0min 52sec
# #### game 17
# time_game : 0H 0min 51sec
# #### game 18
# time_game : 0H 0min 51sec
# #### game 19
# time_game : 0H 0min 51sec
# time : 0H 16min 58sec

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    
  
    player_d_TSMH_c_01_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,0.1)
    player_d_TSMH_c_1_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1)
    player_d_TSMH_c_10_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10)
    player_d_TSMH_c_100_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,100)
    player_d_TSMH_c_1000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1000)
    player_d_TSMH_c_10000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10000)


    referee_TSMH_c_01_pas_5_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_01_pas_5)
    referee_TSMH_c_1_pas_5_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_1_pas_5)
    referee_TSMH_c_10_pas_5_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_10_pas_5)
    referee_TSMH_c_100_pas_5_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_100_pas_5)
    referee_TSMH_c_1000_pas_5_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_1000_pas_5)
    referee_TSMH_c_10000_pas_5_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_10000_pas_5)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 3min 47sec
# #### game 1
# time_game : 0H 3min 49sec
# #### game 2
# time_game : 0H 3min 52sec
# #### game 3
# time_game : 0H 3min 51sec
# #### game 4
# time_game : 0H 3min 51sec
# #### game 5
# time_game : 0H 3min 13sec
# #### game 6
# time_game : 0H 3min 0sec
# #### game 7
# time_game : 0H 2min 55sec
# #### game 8
# time_game : 0H 3min 21sec
# #### game 9
# time_game : 0H 2min 57sec
# #### game 10
# time_game : 1H 14min 23sec
# #### game 11
# time_game : 0H 4min 12sec
# #### game 12
# time_game : 0H 4min 13sec
# #### game 13
# time_game : 0H 4min 12sec
# #### game 14
# time_game : 0H 4min 12sec
# #### game 15
# time_game : 0H 4min 15sec
# #### game 16
# time_game : 0H 4min 0sec
# #### game 17
# time_game : 0H 4min 9sec
# #### game 18
# time_game : 0H 3min 53sec
# #### game 19
# time_game : 0H 3min 51sec
# time : 2H 26min 7sec

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    ###Reboot player
    player_d_TSMH_c_01_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,0.1)
    player_d_TSMH_c_1_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1)
    player_d_TSMH_c_10_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10)
    player_d_TSMH_c_100_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,100)
    player_d_TSMH_c_1000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1000)
    player_d_TSMH_c_10000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10000)
    ###Play game
    referee_Oracle_5000trials_20games_thetas_final.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_thetas_final.play_game(player_d_Random)

    referee_TSMH_c_01_pas_10_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_01_pas_10)
    referee_TSMH_c_1_pas_10_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_1_pas_10)
    referee_TSMH_c_10_pas_10_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_10_pas_10)
    referee_TSMH_c_100_pas_10_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_100_pas_10)
    referee_TSMH_c_1000_pas_10_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_1000_pas_10)
    referee_TSMH_c_10000_pas_10_5000trials_20games_thetas_final.play_game(player_d_TSMH_c_10000_pas_10)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 10min 27sec
# #### game 1
# time_game : 1H 11min 33sec
# #### game 2
# time_game : 0H 9min 24sec
# #### game 3
# time_game : 0H 9min 26sec
# #### game 4
# time_game : 0H 9min 30sec
# #### game 5
# time_game : 0H 9min 29sec
# #### game 6
# time_game : 0H 9min 24sec
# #### game 7
# time_game : 0H 9min 27sec
# #### game 8
# time_game : 0H 9min 28sec
# #### game 9
# time_game : 0H 8min 26sec
# #### game 10
# time_game : 0H 7min 46sec
# #### game 11
# time_game : 0H 8min 33sec
# #### game 12
# time_game : 0H 8min 26sec
# #### game 13
# time_game : 0H 8min 52sec
# #### game 14
# time_game : 0H 8min 19sec
# #### game 15
# time_game : 0H 8min 12sec
# #### game 16
# time_game : 0H 8min 5sec
# #### game 17
# time_game : 0H 8min 5sec
# #### game 18
# time_game : 0H 8min 7sec
# #### game 19
# time_game : 0H 8min 9sec
# time : 3H 59min 20sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_thetas_final.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'b-', label='TSHM, c = 0.1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'b--', label='TSHM, c = 0.1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'b:', label='TSHM, c = 0.1, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'g-', label='TSHM, c = 1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'g--', label='TSHM, c = 1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'g:', label='TSHM, c = 1, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = 'solid', label='TSHM, c = 10, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = '--', label='TSHM, c = 10, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = ':', label='TSHM, c = 10, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = 'solid', label='TSHM, c = 100, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = '--', label='TSHM, c = 100, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = ':', label='TSHM, c = 100, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = 'solid', label='TSHM, c = 1000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = '--', label='TSHM, c = 1000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = ':', label='TSHM, c = 1000, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = 'solid', label='TSHM, c = 10000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = '--', label='TSHM, c = 10000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = ':', label='TSHM, c = 10000, steps= 1')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ("Test for interaction of step's number and length, on "+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_thetas_final.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'r-', label='Random')


plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'b-', label='TSHM, c = 0.1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'b--', label='TSHM, c = 0.1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'b:', label='TSHM, c = 0.1, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'g-', label='TSHM, c = 1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'g--', label='TSHM, c = 1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'g:', label='TSHM, c = 1, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = 'solid', label='TSHM, c = 1000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = '--', label='TSHM, c = 1000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = ':', label='TSHM, c = 1000, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = 'solid', label='TSHM, c = 10000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_5_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = '--', label='TSHM, c = 10000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = ':', label='TSHM, c = 10000, steps= 1')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ("Test for interaction of step's number and length on "+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ### write logs

# %%
pwd
# Out:
# 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank\\Test\\interaction\\result\\test_thetas\\theta3\\TSMH_pasXalea'

# %%
cd ..
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\test_thetas

# %%
cd thetas_final/TSMH_pasXc
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\test_thetas\thetas_final\TSMH_pasXc

# %%
with open('referee_Oracle_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_Oracle_5000trials_20games_thetas_final.record_results, file)
with open('referee_Random_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_Random_5000trials_20games_thetas_final.record_results, file)
    
with open('referee_TSMH_c_01_pas_10_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_10_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_1_pas_10_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_10_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_10_pas_10_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_10_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_100_pas_10_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_10_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_1000_pas_10_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_10_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_10000_pas_10_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_10_5000trials_20games_thetas_final.record_results, file)
    
with open('referee_TSMH_c_01_pas_5_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_5_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_1_pas_5_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_5_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_10_pas_5_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_5_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_100_pas_5_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_5_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_1000_pas_5_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_5_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_10000_pas_5_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_5_5000trials_20games_thetas_final.record_results, file)
    
    

with open('referee_TSMH_c_01_pas_1_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_1_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_1_pas_1_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_1_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_10_pas_1_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_1_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_100_pas_1_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_1_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_1000_pas_1_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_1_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_c_10000_pas_1_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_1_5000trials_20games_thetas_final.record_results, file)

# %% [markdown]
# ## Tests TSMH pas + alea

# %%
kappas_desord = [1,0.3,0.6,0.75,0.1]
thetas_final = [0.3,0.2,0.15,0.15,0.15,0.10,0.05,0.05,0.01,0.01]
nb_prop = len(thetas_final)  
nb_place = len(kappas_desord)

# %%
pas = 10
c = 1
pas = [10, 5, 1]
env = Environment_PBM(thetas_final,kappas_desord)

part0 = [np.array([uniform(0, 1) for i  in range(nb_prop)]), np.array([1]+[uniform(0, 1) for i  in range(1,nb_place)])]
 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)

player_TSMH_pas_10_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1,part_suivie=False)

player_TSMH_pas_5_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=5,c=1,part_suivie= False)

player_TSMH_pas_1_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1,part_suivie=False)

# %% [markdown]
# ### Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_thetas_final = Referee(env,nb_trial)
referee_Random_5000trials_20games_thetas_final = Referee(env,nb_trial)


referee_TSMH_pas_10_5000trials_20games_thetas_final = Referee(env,nb_trial)

referee_TSMH_pas_1_5000trials_20games_thetas_final = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    referee_Oracle_5000trials_20games_thetas_final.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_thetas_final.play_game(player_d_Random)
    
    ### Reboot players
    player_TSMH_pas_10_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1,part_suivie=False)

    player_TSMH_pas_1_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1,part_suivie=False)

    ### play game
    referee_TSMH_pas_10_5000trials_20games_thetas_final.play_game(player_TSMH_pas_10_partalea)
    referee_TSMH_pas_1_5000trials_20games_thetas_final.play_game(player_TSMH_pas_1_partalea)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 1H 43min 41sec
# #### game 1
# time_game : 0H 2min 6sec
# #### game 2
# time_game : 0H 2min 13sec
# #### game 3
# time_game : 0H 2min 16sec
# #### game 4
# time_game : 0H 2min 18sec
# #### game 5
# time_game : 0H 2min 20sec
# #### game 6
# time_game : 0H 2min 23sec
# #### game 7
# time_game : 0H 2min 24sec
# #### game 8
# time_game : 0H 2min 25sec
# #### game 9
# time_game : 0H 2min 25sec
# #### game 10
# time_game : 0H 2min 26sec
# #### game 11
# time_game : 0H 2min 26sec
# #### game 12
# time_game : 0H 2min 27sec
# #### game 13
# time_game : 0H 2min 29sec
# #### game 14
# time_game : 0H 2min 29sec
# #### game 15
# time_game : 0H 2min 30sec
# #### game 16
# time_game : 0H 2min 29sec
# #### game 17
# time_game : 0H 2min 28sec
# #### game 18
# time_game : 0H 2min 29sec
# #### game 19
# time_game : 0H 2min 30sec
# time : 2H 29min 24sec

# %%
referee_TSMH_pas_1_nonalea_5000trials_20games_thetas_final = Referee(env,nb_trial)

referee_TSMH_pas_10_nonalea_5000trials_20games_thetas_final = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_1_nonalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1)
    player_TSMH_pas_10_nonalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1)
    ###Play game
    referee_TSMH_pas_1_nonalea_5000trials_20games_thetas_final.play_game(player_TSMH_pas_1_nonalea)
    referee_TSMH_pas_10_nonalea_5000trials_20games_thetas_final.play_game(player_TSMH_pas_10_nonalea)

    end_game = time.time()   
    print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0time_game : 0H 2min 51sec
# #### game 1time_game : 0H 3min 9sec
# #### game 2time_game : 0H 2min 50sec
# #### game 3time_game : 0H 2min 37sec
# #### game 4time_game : 0H 2min 31sec
# #### game 5time_game : 0H 2min 30sec
# #### game 6time_game : 0H 2min 30sec
# #### game 7time_game : 0H 2min 29sec
# #### game 8time_game : 0H 2min 28sec
# #### game 9time_game : 0H 2min 28sec
# #### game 10time_game : 0H 2min 40sec
# #### game 11time_game : 0H 2min 53sec
# #### game 12time_game : 0H 2min 35sec
# #### game 13time_game : 0H 2min 37sec
# #### game 14time_game : 0H 2min 27sec
# #### game 15time_game : 0H 2min 24sec
# #### game 16time_game : 0H 2min 25sec
# #### game 17time_game : 0H 2min 26sec
# #### game 18time_game : 0H 2min 25sec
# #### game 19time_game : 0H 2min 25sec
# time : 0H 51min 48sec

# %%
referee_TSMH_pas_100_5000trials_10games_thetas_final = Referee(env,nb_trial)

start = time.time()
  
for i in range(10):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_100_partalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=100,c=1,part_suivie=False)
    ### play game
    referee_TSMH_pas_100_5000trials_10games_thetas_final.play_game(player_TSMH_pas_100_partalea)

    end_game = time.time()   
    print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0time_game : 0H 21min 42sec
# #### game 1time_game : 0H 21min 53sec
# #### game 2time_game : 0H 22min 0sec
# #### game 3time_game : 0H 21min 46sec
# #### game 4time_game : 0H 21min 44sec
# #### game 5time_game : 0H 21min 47sec
# #### game 6time_game : 0H 21min 50sec
# #### game 7time_game : 0H 21min 45sec
# #### game 8time_game : 0H 21min 58sec
# #### game 9time_game : 0H 22min 4sec
# time : 3H 38min 33sec

# %%
referee_TSMH_pas_100_nonalea_5000trials_10games_thetas_final = Referee(env,nb_trial)

start = time.time()
  
for i in range(10):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_100_nonalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=100,c=1,part_suivie=True)
    ### play game
    referee_TSMH_pas_100_nonalea_5000trials_10games_thetas_final.play_game(player_TSMH_pas_100_nonalea)

    end_game = time.time()   
    print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0time_game : 0H 23min 4sec
# #### game 1time_game : 0H 23min 46sec
# #### game 2time_game : 0H 22min 26sec
# #### game 3time_game : 0H 22min 38sec
# #### game 4time_game : 0H 23min 37sec
# #### game 5time_game : 0H 24min 13sec
# #### game 6time_game : 0H 20min 38sec
# #### game 7time_game : 0H 20min 46sec
# #### game 8time_game : 0H 19min 14sec
# #### game 9time_game : 0H 14min 34sec
# time : 3H 35min 1sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_thetas_final.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_TSMH_pas_10_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],'b-', label='TSHM, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_pas_1_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],color='purple', label='TSHM,  steps= 1')
plt.plot(trials, np.cumsum(referee_TSMH_pas_100_5000trials_10games_thetas_final.get_regret_expected(), axis=0)[trials],color='orange', label='TSHM,  steps= 100')
plt.plot(trials, np.cumsum(referee_TSMH_pas_1_nonalea_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],color='purple',linestyle='--', label='TSHM,  steps= 1 followed particule')
plt.plot(trials, np.cumsum(referee_TSMH_pas_10_nonalea_5000trials_20games_thetas_final.get_regret_expected(), axis=0)[trials],color='b',linestyle='--', label='TSHM,  steps= 10 followed particule')
plt.plot(trials, np.cumsum(referee_TSMH_pas_100_nonalea_5000trials_10games_thetas_final.get_regret_expected(), axis=0)[trials],color='orange',linestyle='--', label='TSHM,  steps= 100 followed particule ')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on impact of random particule, on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ### write logs

# %%
pwd
# Out:
# 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank\\Test\\interaction\\result\\test_thetas\\thetas_final\\TSMH_pasXalea'

# %%
cd ..
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\test_thetas\thetas_final

# %%
cd TSMH_pasXalea
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\test_thetas\thetas_final\TSMH_pasXalea

# %%
with open('referee_Oracle_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_Oracle_5000trials_20games_thetas_final.record_results, file)
with open('referee_Random_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_Random_5000trials_20games_thetas_final.record_results, file)
    
with open('referee_TSMH_partalea_pas_10_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_pas_10_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_partalea_pas_1_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_pas_1_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_partalea_pas_100_5000trials_10games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_pas_100_5000trials_10games_thetas_final.record_results, file)
    

    
with open('referee_TSMH_pas_1_nonalea_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_pas_1_nonalea_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_pas_10_nonalea_5000trials_20games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_pas_10_nonalea_5000trials_20games_thetas_final.record_results, file)
with open('referee_TSMH_pas_100_nonalea_5000trials_10games_thetas_final.txt', 'w') as file:
    json.dump(referee_TSMH_pas_100_nonalea_5000trials_10games_thetas_final.record_results, file)

# %% [markdown]
# # Thetas [0.3]

# %% [markdown]
# ## Tests TSMH c + pas

# %%
kappas_desord = [1,0.3,0.6,0.75,0.1]
thetas = [0.3,0.1]+[round(uniform(0, 0.1),2) for i  in range(8)]
nb_prop = len(thetas)  
nb_place = len(kappas_desord)

# %%
pas = 10
c = [0.1, 1, 10, 100, 1000, 10000]
pas = [10, 5, 1]
env = Environment_PBM(thetas,kappas_desord)

part0 = [np.array([uniform(0, 1) for i  in range(nb_prop)]), np.array([1]+[uniform(0, 1) for i  in range(1,nb_place)])]
 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)

player_d_TSMH_c_01_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,0.1)
player_d_TSMH_c_1_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1)
player_d_TSMH_c_10_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10)
player_d_TSMH_c_100_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,100)
player_d_TSMH_c_1000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1000)
player_d_TSMH_c_10000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10000)

player_d_TSMH_c_01_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,0.1)
player_d_TSMH_c_1_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1)
player_d_TSMH_c_10_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10)
player_d_TSMH_c_100_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,100)
player_d_TSMH_c_1000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1000)
player_d_TSMH_c_10000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10000)

player_d_TSMH_c_01_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,0.1)
player_d_TSMH_c_1_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1)
player_d_TSMH_c_10_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10)
player_d_TSMH_c_100_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,100)
player_d_TSMH_c_1000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1000)
player_d_TSMH_c_10000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10000)

# %% [markdown]
# ### Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_t3 = Referee(env,nb_trial)
referee_Random_5000trials_20games_t3 = Referee(env,nb_trial)


referee_TSMH_c_01_pas_10_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_1_pas_10_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_10_pas_10_5000trials_20games_t3= Referee(env,nb_trial)
referee_TSMH_c_100_pas_10_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_10_5000trials_20games_t3= Referee(env,nb_trial)
referee_TSMH_c_10000_pas_10_5000trials_20games_t3 = Referee(env,nb_trial)


referee_TSMH_c_01_pas_5_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_1_pas_5_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_10_pas_5_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_100_pas_5_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_5_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_10000_pas_5_5000trials_20games_t3 = Referee(env,nb_trial)


referee_TSMH_c_01_pas_1_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_1_pas_1_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_10_pas_1_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_100_pas_1_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_1000_pas_1_5000trials_20games_t3 = Referee(env,nb_trial)
referee_TSMH_c_10000_pas_1_5000trials_20games_t3 = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    ###Reboot player
    player_d_TSMH_c_01_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,0.1)
    player_d_TSMH_c_1_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1)
    player_d_TSMH_c_10_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10)
    player_d_TSMH_c_100_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,100)
    player_d_TSMH_c_1000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,1000)
    player_d_TSMH_c_10000_pas_10 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,10,10000)
    ###Play game
    referee_Oracle_5000trials_20games_t3.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_t3.play_game(player_d_Random)

    referee_TSMH_c_01_pas_10_5000trials_20games_t3.play_game(player_d_TSMH_c_01_pas_10)
    referee_TSMH_c_1_pas_10_5000trials_20games_t3.play_game(player_d_TSMH_c_1_pas_10)
    referee_TSMH_c_10_pas_10_5000trials_20games_t3.play_game(player_d_TSMH_c_10_pas_10)
    referee_TSMH_c_100_pas_10_5000trials_20games_t3.play_game(player_d_TSMH_c_100_pas_10)
    referee_TSMH_c_1000_pas_10_5000trials_20games_t3.play_game(player_d_TSMH_c_1000_pas_10)
    referee_TSMH_c_10000_pas_10_5000trials_20games_t3.play_game(player_d_TSMH_c_10000_pas_10)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 41min 38sec
# #### game 1
# time_game : 0H 11min 13sec
# #### game 2
# time_game : 0H 11min 2sec
# #### game 3
# time_game : 0H 10min 47sec
# #### game 4
# time_game : 0H 11min 38sec
# #### game 5
# time_game : 0H 9min 50sec
# #### game 6
# time_game : 0H 7min 52sec
# #### game 7
# time_game : 0H 7min 43sec
# #### game 8
# time_game : 0H 7min 23sec
# #### game 9
# time_game : 0H 7min 21sec
# #### game 10
# time_game : 0H 9min 39sec
# #### game 11
# time_game : 0H 9min 47sec
# #### game 12
# time_game : 0H 9min 59sec
# #### game 13
# time_game : 0H 9min 23sec
# #### game 14
# time_game : 0H 8min 45sec
# #### game 15
# time_game : 0H 9min 47sec
# #### game 16
# time_game : 0H 8min 54sec
# #### game 17
# time_game : 0H 8min 33sec
# #### game 18
# time_game : 0H 8min 32sec
# #### game 19
# time_game : 0H 8min 34sec
# time : 3H 38min 29sec

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    
  
    player_d_TSMH_c_01_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,0.1)
    player_d_TSMH_c_1_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1)
    player_d_TSMH_c_10_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10)
    player_d_TSMH_c_100_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,100)
    player_d_TSMH_c_1000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,1000)
    player_d_TSMH_c_10000_pas_5 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,5,10000)


    referee_TSMH_c_01_pas_5_5000trials_20games_t3.play_game(player_d_TSMH_c_01_pas_5)
    referee_TSMH_c_1_pas_5_5000trials_20games_t3.play_game(player_d_TSMH_c_1_pas_5)
    referee_TSMH_c_10_pas_5_5000trials_20games_t3.play_game(player_d_TSMH_c_10_pas_5)
    referee_TSMH_c_100_pas_5_5000trials_20games_t3.play_game(player_d_TSMH_c_100_pas_5)
    referee_TSMH_c_1000_pas_5_5000trials_20games_t3.play_game(player_d_TSMH_c_1000_pas_5)
    referee_TSMH_c_10000_pas_5_5000trials_20games_t3.play_game(player_d_TSMH_c_10000_pas_5)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 4min 13sec
# #### game 1
# time_game : 0H 4min 16sec
# #### game 2
# time_game : 0H 4min 12sec
# #### game 3
# time_game : 0H 4min 22sec
# #### game 4
# time_game : 0H 4min 28sec
# #### game 5
# time_game : 0H 4min 19sec
# #### game 6
# time_game : 0H 4min 16sec
# #### game 7
# time_game : 0H 4min 15sec
# #### game 8
# time_game : 0H 4min 21sec
# #### game 9
# time_game : 0H 4min 21sec
# #### game 10
# time_game : 0H 4min 16sec
# #### game 11
# time_game : 0H 4min 12sec
# #### game 12
# time_game : 0H 4min 14sec
# #### game 13
# time_game : 0H 4min 15sec
# #### game 14
# time_game : 0H 4min 14sec
# #### game 15
# time_game : 0H 4min 13sec
# #### game 16
# time_game : 0H 4min 15sec
# #### game 17
# time_game : 0H 4min 19sec
# #### game 18
# time_game : 0H 4min 14sec
# #### game 19
# time_game : 0H 4min 13sec
# time : 1H 25min 38sec

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
  
    player_d_TSMH_c_01_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,0.1)
    player_d_TSMH_c_1_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1)
    player_d_TSMH_c_10_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10)
    player_d_TSMH_c_100_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,100)
    player_d_TSMH_c_1000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,1000)
    player_d_TSMH_c_10000_pas_1 =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,1,10000)
    
    referee_TSMH_c_01_pas_1_5000trials_20games_t3.play_game(player_d_TSMH_c_01_pas_1)
    referee_TSMH_c_1_pas_1_5000trials_20games_t3.play_game(player_d_TSMH_c_1_pas_1)
    referee_TSMH_c_10_pas_1_5000trials_20games_t3.play_game(player_d_TSMH_c_10_pas_1)
    referee_TSMH_c_100_pas_1_5000trials_20games_t3.play_game(player_d_TSMH_c_100_pas_1)
    referee_TSMH_c_1000_pas_1_5000trials_20games_t3.play_game(player_d_TSMH_c_1000_pas_1)
    referee_TSMH_c_10000_pas_1_5000trials_20games_t3.play_game(player_d_TSMH_c_10000_pas_1)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 1min 6sec
# #### game 1
# time_game : 0H 1min 2sec
# #### game 2
# time_game : 0H 1min 2sec
# #### game 3
# time_game : 0H 1min 1sec
# #### game 4
# time_game : 0H 1min 3sec
# #### game 5
# time_game : 0H 1min 2sec
# #### game 6
# time_game : 0H 1min 2sec
# #### game 7
# time_game : 0H 1min 2sec
# #### game 8
# time_game : 0H 1min 2sec
# #### game 9
# time_game : 0H 1min 7sec
# #### game 10
# time_game : 0H 1min 2sec
# #### game 11
# time_game : 0H 1min 2sec
# #### game 12
# time_game : 0H 1min 2sec
# #### game 13
# time_game : 0H 1min 2sec
# #### game 14
# time_game : 0H 1min 0sec
# #### game 15
# time_game : 0H 0min 55sec
# #### game 16
# time_game : 0H 0min 55sec
# #### game 17
# time_game : 0H 0min 56sec
# #### game 18
# time_game : 0H 0min 55sec
# #### game 19
# time_game : 0H 0min 56sec
# time : 0H 20min 24sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_t3.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_t3.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_10_5000trials_20games_t3.get_regret_expected(), axis=0)[trials],'b-', label='TSHM, c = 0.1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_5_5000trials_20games_t3.get_regret_expected(), axis=0)[trials],'b--', label='TSHM, c = 0.1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_01_pas_1_5000trials_20games_t3.get_regret_expected(), axis=0)[trials],'b:', label='TSHM, c = 0.1, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_10_5000trials_20games_t3.get_regret_expected(), axis=0)[trials],'g-', label='TSHM, c = 1, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_5_5000trials_20games_t3.get_regret_expected(), axis=0)[trials],'g--', label='TSHM, c = 1, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_1_pas_1_5000trials_20games_t3.get_regret_expected(), axis=0)[trials],'g:', label='TSHM, c = 1, steps= 1')


plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_10_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = 'solid', label='TSHM, c = 10, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_5_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = '--', label='TSHM, c = 10, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_10_pas_1_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'orange', linestyle = ':', label='TSHM, c = 10, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_10_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = 'solid', label='TSHM, c = 100, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_5_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = '--', label='TSHM, c = 100, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_100_pas_1_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'black', linestyle = ':', label='TSHM, c = 100, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_10_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = 'solid', label='TSHM, c = 1000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_5_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = '--', label='TSHM, c = 1000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_1000_pas_1_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'purple', linestyle = ':', label='TSHM, c = 1000, steps= 1')

plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_10_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = 'solid', label='TSHM, c = 10000, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_5_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = '--', label='TSHM, c = 10000, steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_c_10000_pas_1_5000trials_20games_t3.get_regret_expected(), axis=0)[trials], color = 'pink', linestyle = ':', label='TSHM, c = 10000, steps= 1')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ### write logs

# %%
pwd
# Out:
# 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank\\Test\\interaction\\test_thetas'

# %%
cd ..
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction

# %%
cd result/test_thetas/theta3/TSMH_pasXc
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\test_thetas\theta3\TSMH_pasXc

# %%
with open('referee_Oracle_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_Oracle_5000trials_20games_t3.record_results, file)
with open('referee_Random_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_Random_5000trials_20games_t3.record_results, file)
    
with open('referee_TSMH_c_01_pas_10_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_10_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_1_pas_10_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_10_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_10_pas_10_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_10_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_100_pas_10_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_10_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_1000_pas_10_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_10_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_10000_pas_10_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_10_5000trials_20games_t3.record_results, file)
    
with open('referee_TSMH_c_01_pas_5_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_5_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_1_pas_5_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_5_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_10_pas_5_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_5_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_100_pas_5_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_5_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_1000_pas_5_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_5_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_10000_pas_5_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_5_5000trials_20games_t3.record_results, file)
    
    

with open('referee_TSMH_c_01_pas_1_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_01_pas_1_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_1_pas_1_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_1_pas_1_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_10_pas_1_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_10_pas_1_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_100_pas_1_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_100_pas_1_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_1000_pas_1_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_1000_pas_1_5000trials_20games_t3.record_results, file)
with open('referee_TSMH_c_10000_pas_1_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_c_10000_pas_1_5000trials_20games_t3.record_results, file)

# %% [markdown]
# ## Tests TSMH pas + alea

# %%
kappas_desord = [1,0.3,0.6,0.75,0.1]
thetas = [0.3,0.1]+[round(uniform(0, 0.1),2) for i  in range(8)]
nb_prop = len(thetas)  
nb_place = len(kappas_desord)

# %%
pas = 10
c = 1
pas = [10, 5, 1]
env = Environment_PBM(thetas,kappas_desord)

part0 = [np.array([uniform(0, 1) for i  in range(nb_prop)]), np.array([1]+[uniform(0, 1) for i  in range(1,nb_place)])]
 

player_d_Oracle = oracle.Oracle(env.get_best_index())
player_d_Random = random_player.Random(nb_prop,nb_place)

player_TSMH_pas_10_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1,part_suivie=False)

player_TSMH_pas_5_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=5,c=1,part_suivie= False)

player_TSMH_pas_1_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1,part_suivie=False)

# %% [markdown]
# ### Game 20 Trial 5000

# %%
nb_trial = 5000
nb_game = 20

referee_Oracle_5000trials_20games_desord = Referee(env,nb_trial)
referee_Random_5000trials_20games_desord = Referee(env,nb_trial)


referee_TSMH_pas_10_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_pas_5_5000trials_20games_desord = Referee(env,nb_trial)
referee_TSMH_pas_1_5000trials_20games_desord = Referee(env,nb_trial)

# %%
start = time.time()
  
for i in range(nb_game):
    print ('#### game '+str(i))
    start_game = time.time()
    referee_Oracle_5000trials_20games_desord.play_game(player_d_Oracle)
    referee_Random_5000trials_20games_desord.play_game(player_d_Random)
    
    ### Reboot players
    player_TSMH_pas_10_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1,part_suivie=False)

    player_TSMH_pas_5_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=5,c=1,part_suivie= False)

    player_TSMH_pas_1_partalea =  TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1,part_suivie=False)

    ### play game
    referee_TSMH_pas_10_5000trials_20games_desord.play_game(player_TSMH_pas_10_partalea)
    referee_TSMH_pas_5_5000trials_20games_desord.play_game(player_TSMH_pas_5_partalea)
    referee_TSMH_pas_1_5000trials_20games_desord.play_game(player_TSMH_pas_1_partalea)

    end_game = time.time()   
    print ('time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0
# time_game : 0H 3min 6sec
# #### game 1
# time_game : 0H 3min 1sec
# #### game 2
# time_game : 0H 2min 58sec
# #### game 3
# time_game : 0H 2min 59sec
# #### game 4
# time_game : 0H 3min 9sec
# #### game 5
# time_game : 0H 4min 14sec
# #### game 6
# time_game : 0H 3min 48sec
# #### game 7
# time_game : 0H 3min 26sec
# #### game 8
# time_game : 0H 2min 54sec
# #### game 9
# time_game : 0H 2min 50sec
# #### game 10
# time_game : 0H 2min 50sec
# #### game 11
# time_game : 0H 2min 48sec
# #### game 12
# time_game : 0H 2min 48sec
# #### game 13
# time_game : 0H 2min 49sec
# #### game 14
# time_game : 0H 2min 46sec
# #### game 15
# time_game : 0H 2min 48sec
# #### game 16
# time_game : 0H 2min 46sec
# #### game 17
# time_game : 0H 3min 2sec
# #### game 18
# time_game : 0H 2min 57sec
# #### game 19
# time_game : 0H 2min 53sec
# time : 1H 1min 2sec

# %%
referee_TSMH_pas_100_5000trials_10games_desord = Referee(env,nb_trial)

start = time.time()
  
for i in range(10):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_100_partalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=100,c=1,part_suivie=False)
    ### play game
    referee_TSMH_pas_100_5000trials_10games_desord.play_game(player_TSMH_pas_100_partalea)

    end_game = time.time()   
    print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0time_game : 0H 23min 21sec
# #### game 1time_game : 0H 23min 2sec
# #### game 2time_game : 0H 23min 4sec
# #### game 3time_game : 0H 23min 8sec
# #### game 4time_game : 9H 46min 51sec
# #### game 5time_game : 0H 20min 8sec
# #### game 6time_game : 0H 20min 42sec
# #### game 7time_game : 0H 19min 11sec
# #### game 8time_game : 0H 18min 13sec
# #### game 9time_game : 0H 18min 32sec
# time : 12H 56min 17sec

# %%
referee_TSMH_pas_1_nonalea_5000trials_20games = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_1_nonalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=1,c=1)
    ###Play game
    referee_TSMH_pas_1_nonalea_5000trials_20games.play_game(player_TSMH_pas_1_nonalea)

    end_game = time.time()   
    #print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# time : 0H 3min 56sec

# %%
referee_TSMH_pas_10_nonalea_5000trials_20games = Referee(env,nb_trial)

start = time.time()
  
for i in range(nb_game):
    #print ('#### game '+str(i))
    start_game = time.time()
    ### Reboot player
    player_TSMH_pas_10_nonalea = TS_MH_kappa_desordonne(nb_prop,nb_place,part0,pas=10,c=1)
    ###Play game
    referee_TSMH_pas_10_nonalea_5000trials_20games.play_game(player_TSMH_pas_10_nonalea)

    end_game = time.time()   
    print ('#### game '+str(i) +'time_game :',time_sec_to_HMS(end_game-start_game)) 
end = time.time()   
print ('time :',time_sec_to_HMS(end-start))
# Out:
# #### game 0time_game : 0H 1min 45sec
# #### game 1time_game : 0H 45min 18sec
# #### game 2time_game : 0H 2min 15sec
# #### game 3time_game : 0H 2min 20sec
# #### game 4time_game : 0H 2min 32sec
# #### game 5time_game : 0H 2min 29sec
# #### game 6time_game : 0H 2min 18sec
# #### game 7time_game : 0H 2min 19sec
# #### game 8time_game : 0H 2min 18sec
# #### game 9time_game : 0H 2min 17sec
# #### game 10time_game : 0H 2min 16sec
# #### game 11time_game : 0H 2min 22sec
# #### game 12time_game : 0H 2min 24sec
# #### game 13time_game : 0H 2min 27sec
# #### game 14time_game : 0H 2min 37sec
# #### game 15time_game : 0H 2min 41sec
# #### game 16time_game : 0H 2min 36sec
# #### game 17time_game : 0H 2min 33sec
# #### game 18time_game : 0H 2min 30sec
# #### game 19time_game : 0H 2min 32sec
# time : 1H 31min 1sec

# %%
trials = [i for i in range(referee_Oracle_5000trials_20games_desord.nb_trials)]
plt.figure(figsize=(10, 10))

#plt.plot(trials, np.cumsum(referee_Oracle_5000trials_20games_desord.get_regret_expected(), axis=0)[trials], label='Oracle')
plt.plot(trials, np.cumsum(referee_Random_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'r-', label='Random')

plt.plot(trials, np.cumsum(referee_TSMH_pas_10_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'b-', label='TSHM, steps= 10')
plt.plot(trials, np.cumsum(referee_TSMH_pas_5_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],'g-', label='TSHM,  steps= 5')
plt.plot(trials, np.cumsum(referee_TSMH_pas_1_5000trials_20games_desord.get_regret_expected(), axis=0)[trials],color='purple', label='TSHM,  steps= 1')
#plt.plot(trials, np.cumsum(referee_TSMH_pas_100_5000trials_10games_desord.get_regret_expected(), axis=0)[trials],color='orange', label='TSHM,  steps= 100')
plt.plot(trials, np.cumsum(referee_TSMH_pas_1_nonalea_5000trials_20games.get_regret_expected(), axis=0)[trials],color='purple',linestyle='--', label='TSHM,  steps= 1 particule suivie')
plt.plot(trials, np.cumsum(referee_TSMH_pas_10_nonalea_5000trials_20games.get_regret_expected(), axis=0)[trials],color='b',linestyle='--', label='TSHM,  steps= 10 particule suivie')


plt.xlabel('Time')
plt.ylabel('Cumulative Expected Regret')
plt.title ('Test on '+ str(nb_game) + ' games  of '+ str(nb_trial)+' trials, MH for '+str(pas)+' pas with kappas unordered')
plt.legend()
plt.grid(True)
plt.loglog()
plt.show()

# %% [markdown]
# ### write logs

# %%
pwd
# Out:
# 'C:\\Users\\gauthieca\\Desktop\\Code_ Thèse\\bandits-to-rank\\Test\\interaction\\result\\test_thetas\\theta3\\TSMH_pasXc'

# %%
cd ..
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\test_thetas\theta3

# %%
cd TSMH_pasXalea
# Out:
# C:\Users\gauthieca\Desktop\Code_ Thèse\bandits-to-rank\Test\interaction\result\test_thetas\theta3\TSMH_pasXalea

# %%
with open('referee_Oracle_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_Oracle_5000trials_20games_desord.record_results, file)
with open('referee_Random_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_Random_5000trials_20games_desord.record_results, file)
    
with open('referee_TSMH_partalea_pas_10_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_pas_10_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_partalea_pas_5_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_pas_5_5000trials_20games_desord.record_results, file)
with open('referee_TSMH_partalea_pas_1_5000trials_20games_t3.txt', 'w') as file:
    json.dump(referee_TSMH_pas_1_5000trials_20games_desord.record_results, file)
#with open('referee_TSMH_partalea_pas_100_5000trials_10games_t3.txt', 'w') as file:
#    json.dump(referee_TSMH_pas_100_5000trials_10games_desord.record_results, file)


with open('referee_TSMH_pas_10_nonalea_5000trials_20games.txt', 'w') as file:
    json.dump(referee_TSMH_pas_10_nonalea_5000trials_20games.record_results, file)
